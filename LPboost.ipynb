# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn import cross_validation
import pulp

# %%
iris =load_iris()
iris.data = iris.data[0:100,:]
iris.target = iris.target[0:100]
#2クラス分類問題に変更する

# %%
for i in range(len(iris["target"])):
    if iris["target"][i] == 0:
        iris["target"][i] = -1
        
train_x,test_x,train_y,test_y = cross_validation.train_test_split(iris.data,iris.target,test_size=0.2)

# %%
#線形計画問題で使用する重みの設定①
for i in range (len(train_x)):
    num = str(i+1)
    print("            w" + num + "= pulp.LpVariable('w" + num + "',0,1/m*v, cat = 'Integer')")
# Out:
#             w1= pulp.LpVariable('w1',0,1/m*v, cat = 'Integer')
#             w2= pulp.LpVariable('w2',0,1/m*v, cat = 'Integer')
#             w3= pulp.LpVariable('w3',0,1/m*v, cat = 'Integer')
#             w4= pulp.LpVariable('w4',0,1/m*v, cat = 'Integer')
#             w5= pulp.LpVariable('w5',0,1/m*v, cat = 'Integer')
#             w6= pulp.LpVariable('w6',0,1/m*v, cat = 'Integer')
#             w7= pulp.LpVariable('w7',0,1/m*v, cat = 'Integer')
#             w8= pulp.LpVariable('w8',0,1/m*v, cat = 'Integer')
#             w9= pulp.LpVariable('w9',0,1/m*v, cat = 'Integer')
#             w10= pulp.LpVariable('w10',0,1/m*v, cat = 'Integer')
#             w11= pulp.LpVariable('w11',0,1/m*v, cat = 'Integer')
#             w12= pulp.LpVariable('w12',0,1/m*v, cat = 'Integer')
#             w13= pulp.LpVariable('w13',0,1/m*v, cat = 'Integer')
#             w14= pulp.LpVariable('w14',0,1/m*v, cat = 'Integer')
#             w15= pulp.LpVariable('w15',0,1/m*v, cat = 'Integer')
# ...

# %%
#線形計画問題で使用する重みの設定②
for i in range (len(train_x)):
    num = str(i+1)
    print("+w"+num+".value()*y["+num+"]*h["+num+"]")
# Out:
# +w1.value()*y[1]*h[1]
# +w2.value()*y[2]*h[2]
# +w3.value()*y[3]*h[3]
# +w4.value()*y[4]*h[4]
# +w5.value()*y[5]*h[5]
# +w6.value()*y[6]*h[6]
# +w7.value()*y[7]*h[7]
# +w8.value()*y[8]*h[8]
# +w9.value()*y[9]*h[9]
# +w10.value()*y[10]*h[10]
# +w11.value()*y[11]*h[11]
# +w12.value()*y[12]*h[12]
# +w13.value()*y[13]*h[13]
# +w14.value()*y[14]*h[14]
# +w15.value()*y[15]*h[15]
# +w16.value()*y[16]*h[16]
# +w17.value()*y[17]*h[17]
# +w18.value()*y[18]*h[18]
# +w19.value()*y[19]*h[19]
# +w20.value()*y[20]*h[20]
# +w21.value()*y[21]*h[21]
# +w22.value()*y[22]*h[22]
# +w23.value()*y[23]*h[23]
# +w24.value()*y[24]*h[24]
# +w25.value()*y[25]*h[25]
# +w26.value()*y[26]*h[26]
# +w27.value()*y[27]*h[27]
# +w28.value()*y[28]*h[28]
# +w29.value()*y[29]*h[29]
# +w30.value()*y[30]*h[30]
# +w31.value()*y[31]*h[31]
# +w32.value()*y[32]*h[32]
# +w33.value()*y[33]*h[33]
# +w34.value()*y[34]*h[34]
# +w35.value()*y[35]*h[35]
# +w36.value()*y[36]*h[36]
# +w37.value()*y[37]*h[37]
# +w38.value()*y[38]*h[38]
# ...

# %%
#線形計画問題で使用する重みの設定③
w = []
w.append(w1)
w.append(w2)
w.append(w3)
w.append(w4)
w.append(w5)
w.append(w6)
w.append(w7)
w.append(w8)
w.append(w9)
w.append(w10)
w.append(w11)
w.append(w12)
w.append(w13)
w.append(w14)
w.append(w15)
w.append(w16)
w.append(w17)
w.append(w18)
w.append(w19)
w.append(w20)
w.append(w21)
w.append(w22)
w.append(w23)
w.append(w24)
w.append(w25)
w.append(w26)
w.append(w27)
w.append(w28)
w.append(w29)
w.append(w30)
w.append(w31)
w.append(w32)
w.append(w33)
w.append(w34)
w.append(w35)
w.append(w36)
w.append(w37)
w.append(w38)
w.append(w39)
w.append(w40)
w.append(w41)
w.append(w42)
w.append(w43)
w.append(w44)
w.append(w45)
w.append(w46)
w.append(w47)
w.append(w48)
w.append(w49)
w.append(w50)
w.append(w51)
w.append(w52)
w.append(w53)
w.append(w54)
w.append(w55)
w.append(w56)
w.append(w57)
w.append(w58)
w.append(w59)
w.append(w60)
w.append(w61)
w.append(w62)
w.append(w63)
w.append(w64)
w.append(w65)
w.append(w66)
w.append(w67)
w.append(w68)
w.append(w69)
w.append(w70)
w.append(w71)
w.append(w72)
w.append(w73)
w.append(w74)
w.append(w75)
w.append(w76)
w.append(w77)
w.append(w78)
w.append(w79)
w.append(w80)

# %%
def weight_linear(a,b):
    weight = np.linalg.inv(a.T.dot(a)).dot(a.T).dot(b)
# .linalg.inv = 逆行列
# .dot = ベクトルの積
    return weight

# %%
#初期分布作成
w = []
for i in range(len(train_x)):
    w.append(1/80)
    
b = 0
m = 80

for i in range(80):
    
            for j in range(4):
                wtrain_x[i,j] = w*train_x[i,j]

# %%
#3,4行目
for t in range(5):
    if t < 3:
        h = weight_linear(wtrain_x,train_y)
        ([np.argmax(w.T.dot(i)) for i in train_x])
#5行目
        sum_weightyh = 0
        for i in range(len(train_y)):
            sum_weightyh = sum_weightyh + w[i]*train_y[i]*h[i]
        if sum_weightyh > b:
            correct_rate = np.zeros(80)
            for i in range(len(train_x)):
                if h[i] == train_y[i]:
                    correct_rate[i] = 1
                else:
                    correct_rate[i] = 0
            v = 80　 - np.count_nonzero(correct_rate
                                       
            w1= pulp.LpVariable('w1',0,1/m*v, cat = 'Integer')
            w2= pulp.LpVariable('w2',0,1/m*v, cat = 'Integer')
            w3= pulp.LpVariable('w3',0,1/m*v, cat = 'Integer')
            w4= pulp.LpVariable('w4',0,1/m*v, cat = 'Integer')
            w5= pulp.LpVariable('w5',0,1/m*v, cat = 'Integer')
            w6= pulp.LpVariable('w6',0,1/m*v, cat = 'Integer')
            w7= pulp.LpVariable('w7',0,1/m*v, cat = 'Integer')
            w8= pulp.LpVariable('w8',0,1/m*v, cat = 'Integer')
            w9= pulp.LpVariable('w9',0,1/m*v, cat = 'Integer')
            w10= pulp.LpVariable('w10',0,1/m*v, cat = 'Integer')
            w11= pulp.LpVariable('w11',0,1/m*v, cat = 'Integer')
            w12= pulp.LpVariable('w12',0,1/m*v, cat = 'Integer')
            w13= pulp.LpVariable('w13',0,1/m*v, cat = 'Integer')
            w14= pulp.LpVariable('w14',0,1/m*v, cat = 'Integer')
            w15= pulp.LpVariable('w15',0,1/m*v, cat = 'Integer')
            w16= pulp.LpVariable('w16',0,1/m*v, cat = 'Integer')
            w17= pulp.LpVariable('w17',0,1/m*v, cat = 'Integer')
            w18= pulp.LpVariable('w18',0,1/m*v, cat = 'Integer')
            w19= pulp.LpVariable('w19',0,1/m*v, cat = 'Integer')
            w20= pulp.LpVariable('w20',0,1/m*v, cat = 'Integer')
            w21= pulp.LpVariable('w21',0,1/m*v, cat = 'Integer')
            w22= pulp.LpVariable('w22',0,1/m*v, cat = 'Integer')
            w23= pulp.LpVariable('w23',0,1/m*v, cat = 'Integer')
            w24= pulp.LpVariable('w24',0,1/m*v, cat = 'Integer')
            w25= pulp.LpVariable('w25',0,1/m*v, cat = 'Integer')
            w26= pulp.LpVariable('w26',0,1/m*v, cat = 'Integer')
            w27= pulp.LpVariable('w27',0,1/m*v, cat = 'Integer')
            w28= pulp.LpVariable('w28',0,1/m*v, cat = 'Integer')
            w29= pulp.LpVariable('w29',0,1/m*v, cat = 'Integer')
            w30= pulp.LpVariable('w30',0,1/m*v, cat = 'Integer')
            w31= pulp.LpVariable('w31',0,1/m*v, cat = 'Integer')
            w32= pulp.LpVariable('w32',0,1/m*v, cat = 'Integer')
            w33= pulp.LpVariable('w33',0,1/m*v, cat = 'Integer')
            w34= pulp.LpVariable('w34',0,1/m*v, cat = 'Integer')
            w35= pulp.LpVariable('w35',0,1/m*v, cat = 'Integer')
            w36= pulp.LpVariable('w36',0,1/m*v, cat = 'Integer')
            w37= pulp.LpVariable('w37',0,1/m*v, cat = 'Integer')
            w38= pulp.LpVariable('w38',0,1/m*v, cat = 'Integer')
            w39= pulp.LpVariable('w39',0,1/m*v, cat = 'Integer')
            w40= pulp.LpVariable('w40',0,1/m*v, cat = 'Integer')
            w41= pulp.LpVariable('w41',0,1/m*v, cat = 'Integer')
            w42= pulp.LpVariable('w42',0,1/m*v, cat = 'Integer')
            w43= pulp.LpVariable('w43',0,1/m*v, cat = 'Integer')
            w44= pulp.LpVariable('w44',0,1/m*v, cat = 'Integer')
            w45= pulp.LpVariable('w45',0,1/m*v, cat = 'Integer')
            w46= pulp.LpVariable('w46',0,1/m*v, cat = 'Integer')
            w47= pulp.LpVariable('w47',0,1/m*v, cat = 'Integer')
            w48= pulp.LpVariable('w48',0,1/m*v, cat = 'Integer')
            w49= pulp.LpVariable('w49',0,1/m*v, cat = 'Integer')
            w50= pulp.LpVariable('w50',0,1/m*v, cat = 'Integer')
            w51= pulp.LpVariable('w51',0,1/m*v, cat = 'Integer')
            w52= pulp.LpVariable('w52',0,1/m*v, cat = 'Integer')
            w53= pulp.LpVariable('w53',0,1/m*v, cat = 'Integer')
            w54= pulp.LpVariable('w54',0,1/m*v, cat = 'Integer')
            w55= pulp.LpVariable('w55',0,1/m*v, cat = 'Integer')
            w56= pulp.LpVariable('w56',0,1/m*v, cat = 'Integer')
            w57= pulp.LpVariable('w57',0,1/m*v, cat = 'Integer')
            w58= pulp.LpVariable('w58',0,1/m*v, cat = 'Integer')
            w59= pulp.LpVariable('w59',0,1/m*v, cat = 'Integer')
            w60= pulp.LpVariable('w60',0,1/m*v, cat = 'Integer')
            w61= pulp.LpVariable('w61',0,1/m*v, cat = 'Integer')
            w62= pulp.LpVariable('w62',0,1/m*v, cat = 'Integer')
            w63= pulp.LpVariable('w63',0,1/m*v, cat = 'Integer')
            w64= pulp.LpVariable('w64',0,1/m*v, cat = 'Integer')
            w65= pulp.LpVariable('w65',0,1/m*v, cat = 'Integer')
            w66= pulp.LpVariable('w66',0,1/m*v, cat = 'Integer')
            w67= pulp.LpVariable('w67',0,1/m*v, cat = 'Integer')
            w68= pulp.LpVariable('w68',0,1/m*v, cat = 'Integer')
            w69= pulp.LpVariable('w69',0,1/m*v, cat = 'Integer')
            w70= pulp.LpVariable('w70',0,1/m*v, cat = 'Integer')
            w71= pulp.LpVariable('w71',0,1/m*v, cat = 'Integer')
            w72= pulp.LpVariable('w72',0,1/m*v, cat = 'Integer')
            w73= pulp.LpVariable('w73',0,1/m*v, cat = 'Integer')
            w74= pulp.LpVariable('w74',0,1/m*v, cat = 'Integer')
            w75= pulp.LpVariable('w75',0,1/m*v, cat = 'Integer')
            w76= pulp.LpVariable('w76',0,1/m*v, cat = 'Integer')
            w77= pulp.LpVariable('w77',0,1/m*v, cat = 'Integer')
            w78= pulp.LpVariable('w78',0,1/m*v, cat = 'Integer')
            w79= pulp.LpVariable('w79',0,1/m*v, cat = 'Integer')
            w80= pulp.LpVariable('w80',0,1/m*v, cat = 'Integer')
            problem = pulp.LpProblem('problem', pulp.LpMinimize)
            
            sum_wyh = 0
            sum_w =0
            b = 0

            for k in range(len(train_x)):
                sum_wyh = sum_wyh + w[k]*train_y[k]*h[i]
                sum_w = sum_w + w[k]
    
            problem += sum_wyh
            problem += sum_w = 1

            status = problem.solve()
            
            w = [w1,w2,w3,w4,w5,w6,w7,w8,w9,w10,w11,w12,w13,w14,w15,w16,
            w17,w18,w19,w20,w21,w22,w23,w24,w25,w26,w27,w28,w29,w30,w31,w32,
            w33,w34,w35,w36,w37,w38,w39,w40,w41,w42,w43,w44,w45,w46,w47,w48,
            w49,w50,w51,w52,w53,w54,w55,w56,w57,w58,w59,w60,w61,w62,w63,w64,
            w65,w66,w67,w68,w69,w70,w71,w72,w73,w74,w75,w76,w77,w78,w79,w80]
            
            b = +w1.value()*y[1]*h[1]+w2.value()*y[2]*h[2]+w3.value()*y[3]*h[3]
                +w4.value()*y[4]*h[4]+w5.value()*y[5]*h[5]+w6.value()*y[6]*h[6]+w7.value()*y[7]*h[7]+w8.value()*y[8]*h[8]+w9.value()*y[9]*h[9]+w10.value()*y[10]*h[10]+w11.value()*y[11]*h[11]+w12.value()*y[12]*h[12]+w13.value()*y[13]*h[13]+w14.value()*y[14]*h[14]+w15.value()*y[15]*h[15]+w16.value()*y[16]*h[16]+w17.value()*y[17]*h[17]+w18.value()*y[18]*h[18]+w19.value()*y[19]*h[19]+w20.value()*y[20]*h[20]+w21.value()*y[21]*h[21]+w22.value()*y[22]*h[22]
                +w23.value()*y[23]*h[23]+w24.value()*y[24]*h[24]+w25.value()*y[25]*h[25]+w26.value()*y[26]*h[26]+w27.value()*y[27]*h[27]+w28.value()*y[28]*h[28]+w29.value()*y[29]*h[29]+w30.value()*y[30]*h[30]+w31.value()*y[31]*h[31]+w32.value()*y[32]*h[32]+w33.value()*y[33]*h[33]+w34.value()*y[34]*h[34]+w35.value()*y[35]*h[35]+w36.value()*y[36]*h[36]+w37.value()*y[37]*h[37]+w38.value()*y[38]*h[38]+w39.value()*y[39]*h[39]+w40.value()*y[40]*h[40]+w41.value()*y[41]*h[41]
                +w42.value()*y[42]*h[42]+w43.value()*y[43]*h[43]+w44.value()*y[44]*h[44]+w45.value()*y[45]*h[45]+w46.value()*y[46]*h[46]+w47.value()*y[47]*h[47]+w48.value()*y[48]*h[48]+w49.value()*y[49]*h[49]
                +w50.value()*y[50]*h[50]+w51.value()*y[51]*h[51]+w52.value()*y[52]*h[52]+w53.value()*y[53]*h[53]+w54.value()*y[54]*h[54]+w55.value()*y[55]*h[55]+w56.value()*y[56]*h[56]+w57.value()*y[57]*h[57]+w58.value()*y[58]*h[58]+w59.value()*y[59]*h[59]+w60.value()*y[60]*h[60]+w61.value()*y[61]*h[61]+w62.value()*y[62]*h[62]+w63.value()*y[63]*h[63]+w64.value()*y[64]*h[64]+w65.value()*y[65]*h[65]+w66.value()*y[66]*h[66]+w67.value()*y[67]*h[67]+w68.value()*y[68]*h[68]+w69.value()*y[69]*h[69]
                +w70.value()*y[70]*h[70]+w71.value()*y[71]*h[71]+w72.value()*y[72]*h[72]+w73.value()*y[73]*h[73]+w74.value()*y[74]*h[74]+w75.value()*y[75]*h[75]+w76.value()*y[76]*h[76]+w77.value()*y[77]*h[77]+w78.value()*y[78]*h[78]+w79.value()*y[79]*h[79]+w80.value()*y[80]*h[80]

    
else:
    T = t-1
    break

# %%
#目的関数と制約条件の設定
problem = pulp.LpProblem('problem', pulp.LpMinimize)
sum_wyh = 0
sum_w =0
b = 0

for k in range(len(train_x)):
    sum_wyh = sum_wyh + w[k]*train_y[k]*h[i]
    sum_w = sum_w + w[k]
    
#minimize    
problem += sum_wyh

#subject
problem += sum_w = 1

status = problem.solve()

w = [w1,w2,w3,w4,w5,w6,w7,w8,w9,w10,w11,w12,w13,w14,w15,w16,
     w17,w18,w19,w20,w21,w22,w23,w24,w25,w26,w27,w28,w29,w30,w31,w32,
     w33,w34,w35,w36,w37,w38,w39,w40,w41,w42,w43,w44,w45,w46,w47,w48,
     w49,w50,w51,w52,w53,w54,w55,w56,w57,w58,w59,w60,w61,w62,w63,w64,
     w65,w66,w67,w68,w69,w70,w71,w72,w73,w74,w75,w76,w77,w78,w79,w80]

b = w1.value()*y[1]*h[1] +
    w2.value()*y[2]*h[2] +
    w3.value()*y[3]*h[3] +
    w4.value()*y[4]*h[4] +
    w5.value()*y[5]*h[5] +
    w6.value()*y[6]*h[6] +
    w7.value()*y[7]*h[7] +
    w8.value()*y[8]*h[8] +
    w9.value()*y[9]*h[9] +
    w10.value()*y[10]*h[10] +
    w11.value()*y[11]*h[11] +
    w12.value()*y[12]*h[12] +
    w13.value()*y[13]*h[13] +
    w14.value()*y[14]*h[14] +
    w15.value()*y[15]*h[15] +
    w16.value()*y[16]*h[16] +
    w17.value()*y[17]*h[17] +
    w18.value()*y[18]*h[18] +
    w19.value()*y[19]*h[19] +
    w20.value()*y[20]*h[20] +
    w21.value()*y[21]*h[21] +
    w22.value()*y[22]*h[22] +
    w23.value()*y[23]*h[23] +
    w24.value()*y[24]*h[24] +
    w25.value()*y[25]*h[25] +
    w26.value()*y[26]*h[26] +
    w27.value()*y[27]*h[27] +
    w28.value()*y[28]*h[28] +
    w29.value()*y[29]*h[29] +
    w30.value()*y[30]*h[30] +
    w31.value()*y[31]*h[31] +
    w32.value()*y[32]*h[32] +
    w33.value()*y[33]*h[33] +
    w34.value()*y[34]*h[34] +
    w35.value()*y[35]*h[35] +
    w36.value()*y[36]*h[36] +
    w37.value()*y[37]*h[37] +
    w38.value()*y[38]*h[38] +
    w39.value()*y[39]*h[39] +
    w40.value()*y[40]*h[40] +
    w41.value()*y[41]*h[41] +
    w42.value()*y[42]*h[42] +
    w43.value()*y[43]*h[43] +
    w44.value()*y[44]*h[44] +
    w45.value()*y[45]*h[45] +
    w46.value()*y[46]*h[46] +
    w47.value()*y[47]*h[47] +
    w48.value()*y[48]*h[48] +
    w49.value()*y[49]*h[49] +
    w50.value()*y[50]*h[50] +
    w51.value()*y[51]*h[51] +
    w52.value()*y[52]*h[52] +
    w53.value()*y[53]*h[53] +
    w54.value()*y[54]*h[54] +
    w55.value()*y[55]*h[55] +
    w56.value()*y[56]*h[56] +
    w57.value()*y[57]*h[57] +
    w58.value()*y[58]*h[58] +
    w59.value()*y[59]*h[59] +
    w60.value()*y[60]*h[60] +
    w61.value()*y[61]*h[61] +
    w62.value()*y[62]*h[62] +
    w63.value()*y[63]*h[63] +
    w64.value()*y[64]*h[64] +
    w65.value()*y[65]*h[65] +
    w66.value()*y[66]*h[66] +
    w67.value()*y[67]*h[67] +
    w68.value()*y[68]*h[68] +
    w69.value()*y[69]*h[69] +
    w70.value()*y[70]*h[70] +
    w71.value()*y[71]*h[71] +
    w72.value()*y[72]*h[72] +
    w73.value()*y[73]*h[73] +
    w74.value()*y[74]*h[74] +
    w75.value()*y[75]*h[75] +
    w76.value()*y[76]*h[76] +
    w77.value()*y[77]*h[77] +
    w78.value()*y[78]*h[78] +
    w79.value()*y[79]*h[79] +
    w80.value()*y[80]*h[80]
# Out:
#   File "<ipython-input-127-ebcca67b120c>", line 4
#     problem = pulp.LpProblem('problem', pulp.LpMinimize)
#           ^
# IndentationError: expected an indented block

# %%
for i in range(3):
    
    a = 1+2
    +3

# %%
a
# Out:
# 1
